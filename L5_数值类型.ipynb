# %% [markdown]
# # 多态
# 多态：操作的意义由操作对象的属性决定。
# 如：在整数是'+'为两数相加，在字符串时则为合并。

# %% [markdown]
# # str和repr显示格式
# str和repr都会把任意对象转换成对应的字符串表示。
# repr:带有额外细节
# str:一般用途

# %%
repr('spam')
# Out:
# "'spam'"

# %%
str('spam')
# Out:
# 'spam'

# %%
1.1 + 2.2 == 3.3
# Out:
# False

# %%
1.1 + 2.2
# Out:
# 3.3000000000000003

# %%
int(1.1) + int(2.2)
# Out:
# 3
