# %% [markdown]
# # 避免混合使用制表符和空格
# 请只使用其中一种。

# %% [markdown]
# # 真值和布尔测试
# 在Python中：
# 1. 所有对象都有一个固有的布尔真/假值
# 2. 任何非零数字或非空对象都为真
# 3. 数字零、空对象以及特殊对象None都被认作是假
# 4. 比较和相等测试会递归地应用到数据结构中
# 5. 比较和相等测试会返回True或False
# 6. 布尔and和or运算符会返回真或假的操作数对象
